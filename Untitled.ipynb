# %%
 [round(random.uniform(1, 101),1) for _ in range (10)]
# Out:
# [20.2, 57.5, 96.3, 43.0, 78.4, 61.8, 55.1, 21.8, 100.2, 16.9]

# %%
 random.sample(range(1, 101), 10)
# Out:
# [92, 82, 1, 99, 89, 71, 52, 38, 8, 85]

# %%
import random

# %%
import numpy as np

# %%
sum([82.6,90.0,48.4,46.4])
# Out:
# 267.4

# %%
sum([4.2,100.2,55.1,61.8])
# Out:
# 221.3

# %%
267.4/221.3
# Out:
# 1.2083145051965656

# %%
21.8*1.2083
# Out:
# 26.34094

# %%
sum([90.0,48.4,46.4])
# Out:
# 184.8

# %%
sum([55.1, 100.2, 4.2])
# Out:
# 159.5

# %%
184.8/159.5
# Out:
# 1.1586206896551725

# %%
16.9*1.1586
# Out:
# 19.58034

# %%
sum([48.4,46.4,90.0])
# Out:
# 184.8

# %%
sum([100.2,4.2,55.1])
# Out:
# 159.5

# %%
184.8/159.5
# Out:
# 1.1586206896551725

# %%
16.9*1.1586
# Out:
# 19.58034

# %%
sum([90.0,0,48.4,0,46.4])
# Out:
# 184.8

# %%
sum([55.1,0,100.2,0,4.2])
# Out:
# 159.5

# %%
184.8/159.5
# Out:
# 1.1586206896551725

# %%
21.8*1.1586
# Out:
# 25.25748
